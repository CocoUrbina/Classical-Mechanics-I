# %% [markdown]
# Tarea 1
#
# Mecánica Teórica I (FS0534)
#
# Prof. Fabián Vásquez Sancho
#
# Edwin A. Urbina-Quiroz | A76588
#
# ---

# %% [markdown]
# Vamos a ver
#
# \begin{equation}
# x
# \end{equation}
